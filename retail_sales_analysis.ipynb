# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
dataset = pd.read_csv("retail_sales_dataset.csv")
dataset.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
dataset.isna().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
dataset.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %%
modified_dataset = dataset.apply(pd.to_numeric, errors='coerce').astype("float")
modified_dataset

modified_dataset.dtypes
# Out:
# Transaction ID      float64
# Date                float64
# Customer ID         float64
# Gender              float64
# Age                 float64
# Product Category    float64
# Quantity            float64
# Price per Unit      float64
# Total Amount        float64
# dtype: object

# %%
modified_dataset
# Out:
#      Transaction ID  Date  Customer ID  Gender   Age  Product Category  \
# 0               1.0   NaN          NaN     NaN  34.0               NaN
# 1               2.0   NaN          NaN     NaN  26.0               NaN
# 2               3.0   NaN          NaN     NaN  50.0               NaN
# 3               4.0   NaN          NaN     NaN  37.0               NaN
# 4               5.0   NaN          NaN     NaN  30.0               NaN
# ..              ...   ...          ...     ...   ...               ...
# 995           996.0   NaN          NaN     NaN  62.0               NaN
# 996           997.0   NaN          NaN     NaN  52.0               NaN
# 997           998.0   NaN          NaN     NaN  23.0               NaN
# 998           999.0   NaN          NaN     NaN  36.0               NaN
# 999          1000.0   NaN          NaN     NaN  47.0               NaN
#
#      Quantity  Price per Unit  Total Amount
# 0         3.0            50.0         150.0
# 1         2.0           500.0        1000.0
# 2         1.0            30.0          30.0
# 3         1.0           500.0         500.0
# 4         2.0            50.0         100.0
# ..        ...             ...           ...
# 995       1.0            50.0          50.0
# 996       3.0            30.0          90.0
# 997       4.0            25.0         100.0
# 998       3.0            50.0         150.0
# 999       4.0            30.0         120.0
#
# [1000 rows x 9 columns]

# %%
modified_dataset.fillna(value=0, inplace=True)
modified_dataset
# Out:
#      Transaction ID  Date  Customer ID  Gender   Age  Product Category  \
# 0               1.0   0.0          0.0     0.0  34.0               0.0
# 1               2.0   0.0          0.0     0.0  26.0               0.0
# 2               3.0   0.0          0.0     0.0  50.0               0.0
# 3               4.0   0.0          0.0     0.0  37.0               0.0
# 4               5.0   0.0          0.0     0.0  30.0               0.0
# ..              ...   ...          ...     ...   ...               ...
# 995           996.0   0.0          0.0     0.0  62.0               0.0
# 996           997.0   0.0          0.0     0.0  52.0               0.0
# 997           998.0   0.0          0.0     0.0  23.0               0.0
# 998           999.0   0.0          0.0     0.0  36.0               0.0
# 999          1000.0   0.0          0.0     0.0  47.0               0.0
#
#      Quantity  Price per Unit  Total Amount
# 0         3.0            50.0         150.0
# 1         2.0           500.0        1000.0
# 2         1.0            30.0          30.0
# 3         1.0           500.0         500.0
# 4         2.0            50.0         100.0
# ..        ...             ...           ...
# 995       1.0            50.0          50.0
# 996       3.0            30.0          90.0
# 997       4.0            25.0         100.0
# 998       3.0            50.0         150.0
# 999       4.0            30.0         120.0
#
# [1000 rows x 9 columns]

# %%
X = modified_dataset.drop(columns="Total Amount")
X
# Out:
#      Transaction ID  Date  Customer ID  Gender   Age  Product Category  \
# 0               1.0   0.0          0.0     0.0  34.0               0.0
# 1               2.0   0.0          0.0     0.0  26.0               0.0
# 2               3.0   0.0          0.0     0.0  50.0               0.0
# 3               4.0   0.0          0.0     0.0  37.0               0.0
# 4               5.0   0.0          0.0     0.0  30.0               0.0
# ..              ...   ...          ...     ...   ...               ...
# 995           996.0   0.0          0.0     0.0  62.0               0.0
# 996           997.0   0.0          0.0     0.0  52.0               0.0
# 997           998.0   0.0          0.0     0.0  23.0               0.0
# 998           999.0   0.0          0.0     0.0  36.0               0.0
# 999          1000.0   0.0          0.0     0.0  47.0               0.0
#
#      Quantity  Price per Unit
# 0         3.0            50.0
# 1         2.0           500.0
# 2         1.0            30.0
# 3         1.0           500.0
# 4         2.0            50.0
# ..        ...             ...
# 995       1.0            50.0
# 996       3.0            30.0
# 997       4.0            25.0
# 998       3.0            50.0
# 999       4.0            30.0
#
# [1000 rows x 8 columns]

# %%
y = modified_dataset["Total Amount"]
y
# Out:
# 0       150.0
# 1      1000.0
# 2        30.0
# 3       500.0
# 4       100.0
#         ...
# 995      50.0
# 996      90.0
# 997     100.0
# 998     150.0
# 999     120.0
# Name: Total Amount, Length: 1000, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model_predictions = model.predict(X_test)

# %%
r2_score = r2_score(y_test, model_predictions)
r2_score
# Out:
# 0.8600704946025333
